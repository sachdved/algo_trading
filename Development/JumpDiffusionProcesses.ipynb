# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
bs = np.random.rand(10000)

# %%
bs
# Out:
# array([0.63323822, 0.15578947, 0.06977502, ..., 0.7948652 , 0.2130302 ,
#        0.04224838])

# %%
min(bs)
# Out:
# np.float64(1.0010096982714392)

# %%
max(bs)
# Out:
# np.float64(9.515901441838581)

# %%
np.argmax(bs)
# Out:
# np.int64(9423)

# %%
data[[1940, 9423],:].ravel()
# Out:
# array([ -0.90760888,   0.61161762,   0.82291066, ...,  -9.16030236,
#        -26.11382026,   4.4072561 ])

# %%
plt.hist(data[[1940, 9423],:].ravel(), density = True, bins=1000)
plt.yscale('log')

# %%
data = np.zeros((10000, 100000))

for r in range(10000):
    data[r, :] = np.random.laplace(
        loc = 0, scale = bs[r], size = 100000
    )

# %%
plt.hist(data.ravel(), density = True, bins=1000)
plt.yscale('log')
plt.ylim(10**-2, 10**1)
# Out:
# (0.01, 10)

# %%
def jump_diffusion_simulator(
    
) -> np.array:
    """
    Implements jump diffusion processes.

    Jump-diffusion is comprised of two components - weiner noise and a poission process
    with noise of an unknown distribution.

    dX_t = (X - \mu) dt + \sigma^{2} dW_{t} + 
    """
